# %%
import pandas as pd

# %%
df_csv = pd.read_csv("../otherfiles/sample_data.csv")

# %%
print(df_csv)
# Out:
#    id       name              email      city
# 0   1      maria    maria@gmail.com   chicago
# 1   2       john   john@outlook.com    dallas
# 2   3        dan      dan@yahoo.com   atlanta
# 3   4   fernando      fnd@gmail.com  san jose
# 4   5  christine  christine@xyz.com   memphis

# %% [markdown]
# To view metadata information

# %%
# info() gives entire information about the dataframe.

df_csv.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5 non-null      int64
#  1   name    5 non-null      str
#  2   email   5 non-null      str
#  3   city    5 non-null      str
# dtypes: int64(1), str(3)
# memory usage: 292.0 bytes

# %%
# To view metadata
df_csv.columns
# Out:
# Index(['id', 'name', 'email', 'city'], dtype='str')

# %%
print(df_csv.columns)
# Out:
# Index(['id', 'name', 'email', 'city'], dtype='str')

# %%
print(df_csv.dtypes)
# Out:
# id       int64
# name       str
# email      str
# city       str
# dtype: object

# %%
# Returns number of records and columns 
# 5, 4 --> 5 are records and 4 are columns

df_csv.shape
# Out:
# (5, 4)

# %%
df_csv.head(10)
# Out:
#    id       name              email      city
# 0   1      maria    maria@gmail.com   chicago
# 1   2       john   john@outlook.com    dallas
# 2   3        dan      dan@yahoo.com   atlanta
# 3   4   fernando      fnd@gmail.com  san jose
# 4   5  christine  christine@xyz.com   memphis

# %%
df_csv
# Out:
#    id       name              email      city
# 0   1      maria    maria@gmail.com   chicago
# 1   2       john   john@outlook.com    dallas
# 2   3        dan      dan@yahoo.com   atlanta
# 3   4   fernando      fnd@gmail.com  san jose
# 4   5  christine  christine@xyz.com   memphis

# %%
df_csv.tail(10)
# Out:
#    id       name              email      city
# 0   1      maria    maria@gmail.com   chicago
# 1   2       john   john@outlook.com    dallas
# 2   3        dan      dan@yahoo.com   atlanta
# 3   4   fernando      fnd@gmail.com  san jose
# 4   5  christine  christine@xyz.com   memphis
